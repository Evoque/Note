# %% [markdown]
# ## 功能模块梳理
#
# - #### 基础数据管理
# - #### 计划编制及管理
# - #### 生产调度 & 报表管理
# - #### 板坯库管理
# - #### 成品库管理
# - #### 发货管理
# - #### 钢卷质量管理
# - #### 轧辊管理
# - #### 通信管理(二级 & ERP之间的通信管理)
# - #### 安全管理(SOA平台已经包含)

# %% [markdown]
# ## 备忘
#
# - 项目包含模块较多，着重依照现有功能实现v1.0的功能复制；
# - 详细的项目进度；
# - 模块分工(包括业务梳理&功能实现)；
# - 测试相关：测试环境搭建、功能测试、测试用例(业务场景模拟)、性能测试；
# - 产品化的考虑；
# - 工程化的考虑；

# %% [markdown]
# ## X3 组织结构
#
# - 基础数据管理（DJX）
# - 连铸信息管理（DJX）
# - 轧辊信息管理（WS）
# - 计划编制信息管理（WS）
# - 生产调度管理（WS）
# - 钢卷质量管理（WS）
# - 板坯库管理（ZHW）
# - 钢卷库管理（ZHW）
# - 中板管理（DJX）
# - 精整管理（ZHW）

# %% [markdown]
# ## 基础数据管理
#
# - PDI基础规范维护
#     + 卷曲温度公差维护
#     + 粗扎温度公差维护
#     + 打捆标准维护
#     + 厚度公差维护
#     + 加热温度维护
#     + 宽度公差维护
#     + 可生产钢种维护
#     + 取样规范维护
#     + 凸度及平直度公差维护
#     + 终轧温度公差维护
#
#
# - PDI基础规范查询
#     + 厚度公差查询
#     + 加热温度查询
#     + 宽度公差查询
#     + PDI数据测试
#
#
# - 其它规范表维护
#     + 板坯化学成分限制
#     + 钢号名称对照
#     + 牌号产品名称对照表维护
#     + 牌号钢号对照表维护
#
#
# + 板坯最大侧压量维护
# + 生产数据整理

# %% [markdown]
# ## 连铸信息管理
# - 板坯原始数据维护
# - DHCR板坯原始数据维护
# - 化学成分维护

# %% [markdown]
# ## 中板管理

# %% [markdown]
# ## 板坯库管理
# - 库区管理
#     - 板坯垛位管理
#     - 板坯垛位查询
#     - 板坯倒垛
#
# - 板坯库位展现
#     - 查看库位图
#     - 配置库位图
#
# - 板坯入库管理
#     - DHCR板坯入库
#     - 板坯入库
#     - 返库板坯入库
#
# - 板坯库盘点
#     - 盘亏及退坯处理
#     - 板坯列印功能
#     - 板坯盘库盈亏查询
#     - 板坯盘盈处理信息
#
# - 板坯出库管理
#     - 板坯出库队列发送
#
# - 板坯信息管理
#     - 板坯号变更
#     - 板坯规格判定
#     - 板坯退废改判
#     - 板坯数据维护
#     - 板坯质量封锁
#     - 板坯质量解锁
#     - 板坯状态修正
#     - 板坯钢种对应成品钢种
#
# - 板坯统计与报表
#     - 在库板坯规格统计
#     - 板坯收发存统计报表
#     - 板坯库存明细报表功能
#     - 板坯库存统计报表
#     - 板坯库入库明细统计表功能
#     - 炼钢证卡信息统计业务功能
#     - 钢坯异议情况功能
#     - 板坯入库日报表功能
#     - 板坯出库日报表功能
#     - 板坯库存结构明细功能
#     - 板坯库存货盘点功能
#     - 板坯库倒垛明细表功能
#     - 板坯出库明细功能
#     - 板坯入炉轧制班报明细统计表功能
#     - 板坯入库信息按炉查询
#
# - 板坯信息查询
#     - 板坯入出库信息查询
#     - 在库板坯规格查询
#     - 板加区作业计划
#     - 板坯信息查询
#     - 在库板坯钢种查询
#     - 炉前炉后吊销坯查询
#     - 板坯数据修改记录
#     - 尺寸异议查询
#     - 倒垛历史纪录查询
#     - 计划热装统计
#     - 轧制计划查询
#     - 热装比统计功能
#
# - 板坯库天车指挥系统
#     - 返库坯入库请求
#     - 板坯入库请求
#     - 板坯上料请求
#     - 板坯倒垛请求
#     - 天车状态查询
#     - 天车任务监控与调整
#     - 执行状态监控
#     - 板坯作业实绩确认
#
# - 板坯库换班

# %% [markdown]
# ## 计划编制信息管理
#
# - 轧制规范维护
#     - 轧制规范维护
# - DHCR计划编制
# - 工单信息查询
# - 工序计划查询
# - 轧制计划编制
# - 轧钢工单分解
# - 轧制计划调整
# - 工序计划维护
# - 打印轧制计划
# - 轧钢工单信息维护
# - 轧制计划吊销
# - 炼钢出钢计划查询
# - 计划单号信息跟踪与处理
# - 工单信息追踪
# - 合同生产规格差异查询
# - 合同执行情况追踪
# - 钢种对应合同功能6
# - 有合同钢板重量功能6
# - 轧制计划历史信息查询
# - 轧制欠量查询功能

# %% [markdown]
# ## 生产调度管理
#
# - 生产计划调度
#     - 板坯吊销
#     - 改轧制规格
#     - 改取样批次
#     - 轧制计划下达
#     - 启动轧制计划
#     - 轧制计划结束
#     - 生产实绩跟踪
#
#
# - 生产信息查询
#     - 加热炉板坯信息查询
#     - 钢卷全程数据查询
#     - 轧制计划查询
#     - 返库坯查询
#     - 消耗板坯及钢卷情况明细表
#     - 系统数据检查
#
#
# - DHCR计划调整
# - 化学成分信息补发
# - 轧线生产报表
#     - 板坯日消耗产出统计报表
#     - 生产明细报表
#     - 生产统计日报
#     - 班组每小时轧制量统计
#     - 生产时间统计
#     - 生产统计报表
#     - 一级统计

# %% [markdown]
# ## 钢卷质量管理
# - 取样登记
#     + 钢卷请验
#     + 试样请验通知单
#     + 初验样标识等级
#     + 复验样标识登记
#     + 请验项目查询
#     + 已请验项目查询
#     + 请验驳回信息处理
#
#
# - 新质量证明书
#     + 船卷产品质量证明书
#     + 产品质量证明书查询
#     + 产品质量证明书打印
#     + 新产品质量证明书510L
#     + 协议品质量证明书业务功能
#
#
# - 质量判定
#     + 性能判定
#     + 表检质量判定
#     + 质量综合判定
#
#
# + 班组轧制信息功能
# + 质量证明书打印
# + 钢卷性能功能
# + 热轧船卷质量证明书功能
# + 钢卷质量综合查询

# %% [markdown]
# ## 钢卷库管理
#
# - 库区管理
#     + 钢卷垛位
#     + 钢卷垛位查询
#     + 钢卷垛位维护
#     + 钢卷历史垛位查询功能
#
#
# - 钢卷库位展现
#     + 查看库位图
#     + 配置库位图
#
#
# - 钢卷入库管理
#     + 钢卷入库CP8
#     + 钢卷撤销入库
#     + 钢卷入库
#     + 物流出库取消处理
#     + 已预约垛位查询与处理
#
# - 钢卷库盘点
#     + 钢卷库盘亏
#     + 钢卷库盘盈
#     + 钢卷盘库记录查询
#     + 钢卷盘库列印(按库)
#     + 钢卷库列印
#     + 钢卷垛位信息
#
# - 钢卷信息实时统计
#     + 按牌号规格进销存实时统计
#         - 半成品进销存实时统计
#         - 半成品库进销存按厚度实时统计
#         - 按规格半成品进销存实时统计
#         - 按规格成品进销存实时统计
#         - 按规格库房进销存实时统计
#     + 钢卷入库报表
#     + 钢卷状态统计报表一
#     + 钢卷状态统计报表二
#     + 钢卷入库明细统计表
#     + 钢卷判定结果统计
#     + 钢卷取样明细统计表
#     + 钢卷合同统计
#     + 钢卷按收货单位统计功能
#     + 半成品库钢卷出库明细
#
#
# - 钢卷信息查询
#     + 计划预约垛位查询
#     + 钢卷入出库查询
#     + 钢卷数据追溯
#     + 钢卷信息查询
#     + 驳回钢卷历史信息查询
#     + 钢卷log查询
#     + 钢卷原始重量查询
#     + 钢卷重量修改记录功能
#
#
# - 钢卷准发管理
#     + 钢卷准发
#     + 标签打印
#     + 船钢标签打印
#     + 条码标签打印
#     + 驳回钢卷信息处理
#     + 驳回及重新准发信息查询
#     + 船钢码单打印
#     + 码单打印
#
#
# - 成品库换班管理
# - 钢卷信息管理
#     + 平整卷删除
#     + 钢卷重量维护
#     + 待处理钢卷查询功能
#     + 钢卷数据封解锁
#     + 已准发钢卷重量修改
#
# - 钢卷库天车指挥系统
#     + CP8天车系统
#         - CP8钢卷入库请求
#         - CP8钢卷倒垛请求
#         - CP8作业实绩确认
#         - CP8任务监控与调整
#
#     + 物运天车系统
#         - 物运钢卷倒垛请求
#         - 物运钢卷出库请求
#         - 物运作业实绩确认
#         - 物运任务监控与调整
#
#     + 平整天车系统
#         - 平整卷入库请求
#         - 平整卷上限请求
#         - 平整倒垛请求
#         - 平整任务监控与调整
#         - 平整作业实绩确认
#
#     + 天车状态查询
#     + 全线天车任务监控

# %% [markdown]
# ## 精整管理

# %% [markdown]
# ## 管理员工具
